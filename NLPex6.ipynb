# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankamb2725/Priyankamb09/blob/main/NLPex6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = """Natural Language Processing is a field of Artificial Intelligence
that focuses on the interaction between computers and humans."""

# %%
sentences = sent_tokenize(text)


words = word_tokenize(text)

sentences
# Out:
# ['Natural Language Processing is a field of Artificial Intelligence\nthat focuses on the interaction between computers and humans.']

# %%
words
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'field',
#  'of',
#  'Artificial',
#  'Intelligence',
#  'that',
#  'focuses',
#  'on',
#  'the',
#  'interaction',
#  'between',
#  'computers',
#  'and',
#  'humans',
#  '.']

# %%
words = [word.lower() for word in words]
words
# Out:
# ['natural',
#  'language',
#  'processing',
#  'is',
#  'a',
#  'field',
#  'of',
#  'artificial',
#  'intelligence',
#  'that',
#  'focuses',
#  'on',
#  'the',
#  'interaction',
#  'between',
#  'computers',
#  'and',
#  'humans',
#  '.']

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalnum() and word not in stop_words]
filtered_words
# Out:
# ['natural',
#  'language',
#  'processing',
#  'field',
#  'artificial',
#  'intelligence',
#  'focuses',
#  'interaction',
#  'computers',
#  'humans']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
stemmed_words
# Out:
# ['natur',
#  'languag',
#  'process',
#  'field',
#  'artifici',
#  'intellig',
#  'focus',
#  'interact',
#  'comput',
#  'human']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
lemmatized_words
# Out:
# ['natural',
#  'language',
#  'processing',
#  'field',
#  'artificial',
#  'intelligence',
#  'focus',
#  'interaction',
#  'computer',
#  'human']
